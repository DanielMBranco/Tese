# %%
#dbutils.fs.unmount("/mnt/mds")

# %%
# %pip install pandas openpyxl

# %%
# Define variables
storage_account_name = "aimasterdata"
storage_account_key = "j0/fRQr9nKT5rozOswNOMIOWQIwyudJH5oDSXINkttZBTP9T1O8phxCx3bJlPjz/kG9gz5Rqd4oW+AStbqPmlw=="
container_name = "mds"
mount_point = "/mnt/mds"

# Mount the storage account
dbutils.fs.mount(
    source=f"wasbs://{container_name}@{storage_account_name}.blob.core.windows.net",
    mount_point=mount_point,
    extra_configs={f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net": storage_account_key}
)

# Verify mount
display(dbutils.fs.ls(mount_point))

# %%
import pandas as pd

# Define file path in Databricks File System (DBFS)
file_path = "/dbfs/mnt/mds/MDS_20250319.xlsx"  # Use "/dbfs/" to access files in Databricks

# Read Excel file using pandas
df_pandas = pd.read_excel(file_path, engine="openpyxl")

# Convert Pandas DataFrame to Spark DataFrame
df_spark = spark.createDataFrame(df_pandas)

# Display DataFrame
df_spark.display()

# %%
permanent_table_name = "MDS"

df_spark.write.format("parquet").saveAsTable(permanent_table_name)
